# %% [markdown]
# # word2vec: How To Prep Word Vectors For Modeling

# %% [markdown]
# ### Train Our Own Model

# %%
# Read in the data, clean it, split it into train and test sets, and then train a word2vec model
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 100)

messages = pd.read_csv('../../../data/spam.csv', encoding='latin-1')
messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["label", "text"]


messages['text_clean'] = messages['text'].apply(lambda x: gensim.utils.simple_preprocess(x))
X_train, X_test, y_train, y_test = train_test_split(messages['text_clean'],
                                                    messages['label'], test_size=0.2)

w2v_model = gensim.models.Word2Vec(X_train,
                                   vector_size=100,
                                   window=5,
                                   min_count=2)

# %% [markdown]
# ### Prep Word Vectors

# %%
# Generate a list of words the word2vec model learned word vectors for
w2v_model.wv.index_to_key # all of the words that appeared in the training data at least twice
# Out:
# ['to',
#  'you',
#  'the',
#  'and',
#  'is',
#  'in',
#  'me',
#  'it',
#  'my',
#  'for',
#  'your',
#  'of',
#  'call',
#  'have',
#  'that',
#  'on',
#  'are',
#  'now',
#  'can',
#  'so',
#  'but',
#  'not',
#  'or',
#  'we',
#  'do',
#  'get',
#  'at',
#  'ur',
#  'no',
#  'with',
#  'if',
#  'be',
#  'just',
#  'will',
#  'this',
#  'gt',
#  'lt',
#  'how',
#  'up',
#  'when',
#  'go',
#  'what',
#  'ok',
#  'free',
#  'from',
#  'all',
#  'll',
#  'know',
#  'out',
#  'then',
#  'got',
#  'like',
#  'good',
#  'there',
#  'come',
#  'day',
#  'am',
#  'its',
#  'was',
#  'he',
#  'only',
#  'time',
#  'love',
#  'want',
#  'text',
#  'txt',
#  'send',
#  'as',
#  'by',
#  'lor',
#  'she',
#  'going',
#  'about',
#  'don',
#  'home',
#  'see',
#  'da',
#  'one',
#  'stop',
#  'today',
#  'need',
#  'still',
#  'sorry',
#  'our',
#  'reply',
#  'back',
#  'mobile',
#  'tell',
#  'been',
#  'they',
#  'dont',
#  'think',
#  'later',
#  'did',
#  'her',
#  'who',
#  'ì_',
#  'take',
#  'new',
#  'please',
#  'any',
#  'phone',
#  'pls',
#  'has',
#  'hi',
#  'here',
#  'where',
#  'msg',
#  'week',
#  'an',
#  're',
#  'some',
#  'dear',
#  'wat',
#  'oh',
#  'had',
#  'claim',
#  'hey',
#  'him',
#  'night',
#  'too',
#  'great',
#  'much',
#  'should',
#  'way',
#  'happy',
#  'well',
#  'work',
#  'hope',
#  'more',
#  'make',
#  've',
#  'say',
#  'already',
#  'yes',
#  'right',
#  'www',
#  'give',
#  'message',
#  'number',
#  'after',
#  'amp',
#  'doing',
#  'really',
#  'them',
#  'won',
#  'im',
#  'meet',
#  'very',
#  'yeah',
#  'also',
#  'said',
#  'morning',
#  'tomorrow',
#  'win',
#  'life',
#  'babe',
#  'last',
#  'thanks',
#  'find',
#  'ask',
#  'prize',
#  'com',
#  'why',
#  'anything',
#  'would',
#  'lol',
#  'cash',
#  'let',
#  'miss',
#  'every',
#  'cos',
#  'even',
#  'something',
#  'urgent',
#  'sure',
#  'contact',
#  'care',
#  'keep',
#  'first',
#  'wait',
#  'buy',
#  'next',
#  'cant',
#  'feel',
#  'nice',
#  'nokia',
#  'gonna',
#  'uk',
#  'pick',
#  'sent',
#  'his',
#  'min',
#  'again',
#  'over',
#  'could',
#  'before',
#  'box',
#  'around',
#  'off',
#  'late',
#  'were',
#  'us',
#  'other',
#  'which',
#  'dun',
#  'wan',
#  'someone',
#  'always',
#  'thing',
#  'tonight',
#  'money',
#  'service',
#  'mins',
#  'down',
#  'place',
#  'help',
#  'went',
#  'gud',
#  'chat',
#  'things',
#  'leave',
#  'friends',
#  'sleep',
#  'per',
#  'many',
#  'told',
#  'soon',
#  'sms',
#  'tone',
#  'best',
#  'special',
#  'smile',
#  'ya',
#  'wish',
#  'holiday',
#  'ìï',
#  'co',
#  'waiting',
#  'customer',
#  'coming',
#  'name',
#  'hello',
#  'friend',
#  'fine',
#  'ppm',
#  'getting',
#  'done',
#  'people',
#  'use',
#  'thk',
#  'same',
#  'haha',
#  'guaranteed',
#  'pm',
#  'class',
#  'god',
#  'lunch',
#  'meeting',
#  'talk',
#  'didn',
#  'st',
#  'thought',
#  'year',
#  'th',
#  'finish',
#  'may',
#  'man',
#  'yet',
#  'ill',
#  'car',
#  'month',
#  'live',
#  'ready',
#  'mind',
#  'try',
#  'person',
#  'pobox',
#  'line',
#  'play',
#  'yo',
#  'days',
#  'better',
#  'cool',
#  'yup',
#  'long',
#  'bit',
#  'being',
#  'heart',
#  'guess',
#  'lar',
#  'awarded',
#  'camera',
#  'house',
#  'thats',
#  'never',
#  'check',
#  'wanna',
#  'draw',
#  'eat',
#  'liao',
#  'stuff',
#  'half',
#  'cs',
#  'quite',
#  'lot',
#  'trying',
#  'few',
#  'chance',
#  'real',
#  'start',
#  'word',
#  'bt',
#  'big',
#  'end',
#  'girl',
#  'world',
#  'job',
#  'forgot',
#  'receive',
#  'problem',
#  'sir',
#  'wk',
#  'pa',
#  'landline',
#  'enjoy',
#  'having',
#  'nite',
#  'part',
#  'dat',
#  'nothing',
#  'tv',
#  'dinner',
#  'ah',
#  'two',
#  'xxx',
#  'watch',
#  'into',
#  'watching',
#  'because',
#  'bad',
#  'aight',
#  'thanx',
#  'hrs',
#  'latest',
#  'wont',
#  'speak',
#  'called',
#  'sat',
#  'account',
#  'boy',
#  'pay',
#  'guys',
#  'ever',
#  'join',
#  'po',
#  'weekend',
#  'den',
#  'face',
#  'offer',
#  'dis',
#  'jus',
#  'baby',
#  'than',
#  'birthday',
#  'video',
#  'though',
#  'remember',
#  'once',
#  'princess',
#  'tmr',
#  'award',
#  'shows',
#  'early',
#  'leh',
#  'apply',
#  'fuck',
#  'plan',
#  'minutes',
#  'hav',
#  'true',
#  'might',
#  'maybe',
#  'another',
#  'nd',
#  'luv',
#  'sweet',
#  'afternoon',
#  'easy',
#  'didnt',
#  'between',
#  'enough',
#  'pain',
#  'collect',
#  'evening',
#  'probably',
#  'must',
#  'wif',
#  'hear',
#  'cost',
#  'hair',
#  'office',
#  'texts',
#  'gift',
#  'working',
#  'wanted',
#  'shopping',
#  'hour',
#  'anyway',
#  'looking',
#  'missing',
#  'reach',
#  'able',
#  'shit',
#  'ringtone',
#  'those',
#  'selected',
#  'times',
#  'bus',
#  'guy',
#  'left',
#  'made',
#  'entry',
#  'look',
#  'actually',
#  'put',
#  'abt',
#  'plus',
#  'xx',
#  'room',
#  'kiss',
#  'okay',
#  'network',
#  'rate',
#  'dunno',
#  'without',
#  'bed',
#  'does',
#  'show',
#  'little',
#  'juz',
#  'til',
#  'wake',
#  'yesterday',
#  'sexy',
#  'fun',
#  'thank',
#  'age',
#  'since',
#  'dad',
#  'asked',
#  'means',
#  'wife',
#  'attempt',
#  'dude',
#  'most',
#  'years',
#  'everything',
#  'collection',
#  'orange',
#  'de',
#  'school',
#  'address',
#  'makes',
#  'wants',
#  'ard',
#  'bring',
#  'while',
#  'shall',
#  'test',
#  'lei',
#  'came',
#  'missed',
#  'coz',
#  'bored',
#  'valid',
#  'town',
#  'havent',
#  'decimal',
#  'xmas',
#  'feeling',
#  'code',
#  'shop',
#  'colour',
#  'mob',
#  'saw',
#  'sad',
#  'else',
#  'price',
#  'book',
#  'until',
#  'family',
#  'alright',
#  'lose',
#  'believe',
#  'huh',
#  'online',
#  'calls',
#  'haf',
#  'old',
#  'answer',
#  'gr',
#  'music',
#  'wot',
#  'wen',
#  'question',
#  'goin',
#  'eve',
#  'dreams',
#  'oso',
#  'mail',
#  'haven',
#  'sae',
#  'todays',
#  'net',
#  'important',
#  'update',
#  'hours',
#  'driving',
#  'making',
#  'chikku',
#  'movie',
#  'saying',
#  'wid',
#  'order',
#  'beautiful',
#  'yourself',
#  'sleeping',
#  'goes',
#  'set',
#  'bonus',
#  'yours',
#  'trip',
#  'weekly',
#  'nt',
#  'run',
#  'tones',
#  'friendship',
#  'comes',
#  'stay',
#  'tot',
#  'details',
#  'leaving',
#  'http',
#  'date',
#  'sister',
#  'both',
#  'either',
#  'vouchers',
#  'away',
#  'calling',
#  'ring',
#  'worry',
#  'final',
#  'tried',
#  'aft',
#  'words',
#  'okie',
#  'change',
#  'smiling',
#  'optout',
#  'busy',
#  'await',
#  'sch',
#  'plz',
#  'story',
#  'charge',
#  'awesome',
#  'these',
#  'row',
#  'games',
#  'food',
#  'head',
#  'wil',
#  'id',
#  'neva',
#  'game',
#  'happen',
#  'rite',
#  'mine',
#  'whats',
#  'together',
#  'club',
#  'msgs',
#  'drive',
#  'drop',
#  'delivery',
#  'auction',
#  'saturday',
#  'gd',
#  'full',
#  'poly',
#  'open',
#  'till',
#  'pics',
#  'mths',
#  'hl',
#  'tomo',
#  'sun',
#  'noe',
#  'lots',
#  'carlos',
#  'post',
#  'hot',
#  'angry',
#  'dating',
#  'services',
#  'took',
#  'says',
#  'brother',
#  'top',
#  'each',
#  'college',
#  'national',
#  'ha',
#  'suite',
#  'land',
#  'congrats',
#  'touch',
#  'lesson',
#  'fast',
#  'started',
#  'sunday',
#  'goodmorning',
#  'email',
#  'hows',
#  'forget',
#  'second',
#  'party',
#  'whatever',
#  'finished',
#  'double',
#  'private',
#  'points',
#  'info',
#  'smoke',
#  'sounds',
#  'girls',
#  'parents',
#  'worth',
#  'alone',
#  'happened',
#  'minute',
#  'visit',
#  'walk',
#  'card',
#  'tel',
#  'pretty',
#  'fr',
#  'everyone',
#  'mean',
#  'far',
#  'project',
#  'wrong',
#  'available',
#  'choose',
#  'news',
#  'anyone',
#  'camcorder',
#  'taking',
#  'pub',
#  'needs',
#  'hurt',
#  'friday',
#  'unlimited',
#  'bout',
#  'yr',
#  'treat',
#  'understand',
#  'freemsg',
#  'knw',
#  'wonderful',
#  'close',
#  'boytoy',
#  'player',
#  'kind',
#  'wkly',
#  'tho',
#  'whole',
#  'read',
#  'blue',
#  'thinking',
#  'gone',
#  'opt',
#  'search',
#  'lovely',
#  'secret',
#  'lands',
#  'found',
#  'gbp',
#  'mum',
#  'operator',
#  'lucky',
#  'savamob',
#  'invited',
#  'telling',
#  'frnds',
#  'felt',
#  'voucher',
#  'messages',
#  'chennai',
#  'tc',
#  'hmmm',
#  'break',
#  'drink',
#  'simple',
#  'lets',
#  'finally',
#  'frm',
#  'least',
#  'sis',
#  'crazy',
#  'winner',
#  'cut',
#  'ni',
#  'anytime',
#  'ten',
#  'smth',
#  'pounds',
#  'prob',
#  'takes',
#  'ltd',
#  'happiness',
#  'numbers',
#  'thinks',
#  'charged',
#  'reading',
#  'comp',
#  'loving',
#  'light',
#  'yar',
#  'decided',
#  'mates',
#  'hold',
#  'earlier',
#  'pic',
#  'nope',
#  'outside',
#  'mom',
#  'christmas',
#  'cum',
#  'hit',
#  'doesn',
#  'darlin',
#  'wasn',
#  'company',
#  'content',
#  'ugh',
#  'valued',
#  'wq',
#  'extra',
#  'unsubscribe',
#  'expires',
#  'balance',
#  'grins',
#  'entered',
#  'hand',
#  'lovable',
#  'statement',
#  'ends',
#  'gotta',
#  'isn',
#  'slowly',
#  'etc',
#  'talking',
#  'quiz',
#  'slow',
#  'case',
#  'reason',
#  'û_',
#  'wit',
#  'met',
#  'die',
#  'used',
#  'loads',
#  'tired',
#  'luck',
#  'mah',
#  'reveal',
#  'mrng',
#  'caller',
#  'seeing',
#  'truth',
#  'mu',
#  'welcome',
#  'mate',
#  'seen',
#  'park',
#  'cause',
#  'gas',
#  'sk',
#  'type',
#  'feels',
#  'oredi',
#  'jay',
#  'congratulations',
#  'area',
#  'eh',
#  'mayb',
#  'gym',
#  'dream',
#  'ge',
#  'fancy',
#  'gn',
#  'heard',
#  'txts',
#  'john',
#  'comin',
#  'course',
#  'confirm',
#  'wana',
#  'na',
#  'snow',
#  'pete',
#  'abiola',
#  'log',
#  'dnt',
#  'plans',
#  'currently',
#  'remove',
#  'uncle',
#  'eg',
#  'ass',
#  'ish',
#  'std',
#  'difficult',
#  'joy',
#  'sea',
#  'march',
#  'phones',
#  'within',
#  'hard',
#  'ipod',
#  'identifier',
#  'move',
#  'sound',
#  'gal',
#  'couple',
#  'somebody',
#  'leaves',
#  'listen',
#  'mr',
#  'rental',
#  'gets',
#  'song',
#  'empty',
#  'ago',
#  'clean',
#  'mobileupd',
#  'rock',
#  'credit',
#  'sex',
#  'complimentary',
#  'fri',
#  'deep',
#  'through',
#  'lost',
#  'nyt',
#  'callertune',
#  'their',
#  'rs',
#  'dogging',
#  'askd',
#  'offers',
#  'months',
#  'correct',
#  'questions',
#  'short',
#  'less',
#  'valentine',
#  'direct',
#  'motorola',
#  'supposed',
#  'nobody',
#  'worried',
#  'own',
#  'monday',
#  'ldn',
#  'usf',
#  'boss',
#  'unless',
#  'ûò',
#  'press',
#  'asap',
#  'valentines',
#  'stupid',
#  'admirer',
#  'charity',
#  'somewhere',
#  'txting',
#  'knew',
#  'kate',
#  'none',
#  'muz',
#  'xy',
#  'rent',
#  'bold',
#  'yrs',
#  'lover',
#  'father',
#  'pass',
#  'swing',
#  'pray',
#  'hg',
#  'meant',
#  'ringtones',
#  'warm',
#  'bslvyl',
#  'paper',
#  'picking',
#  'fone',
#  'bb',
#  'rply',
#  'information',
#  'hiya',
#  'merry',
#  'bath',
#  'loved',
#  'rates',
#  'mobiles',
#  'sub',
#  'using',
#  'gave',
#  'figure',
#  'doin',
#  'enter',
#  'ans',
#  'rd',
#  'lect',
#  'ice',
#  'tickets',
#  'asking',
#  'weeks',
#  'la',
#  'darren',
#  'rcvd',
#  'accept',
#  'hw',
#  'otherwise',
#  'rest',
#  'ex',
#  'spend',
#  'del',
#  'copy',
#  'hungry',
#  'bathe',
#  'sending',
#  'bank',
#  'near',
#  'almost',
#  'reward',
#  'match',
#  'credits',
#  'medical',
#  'apartment',
#  'link',
#  'yep',
#  'usual',
#  'ending',
#  'joined',
#  'booked',
#  'seriously',
#  'wishing',
#  'pound',
#  'moment',
#  'frens',
#  'cheap',
#  'idea',
#  'rain',
#  'immediately',
#  'starts',
#  'digital',
#  'write',
#  'getzed',
#  'completely',
#  'dead',
#  'aha',
#  'wednesday',
#  'sort',
#  'hmv',
#  'laptop',
#  'alex',
#  'point',
#  'wc',
#  'custcare',
#  'kinda',
#  'em',
#  'staying',
#  'terms',
#  'frnd',
#  'il',
#  'door',
#  'however',
#  'myself',
#  'knows',
#  'checking',
#  'hee',
#  'via',
#  'orchard',
#  'wow',
#  ...]

# %%
# Generate aggregated sentence vectors based on the word vectors for each word in the sentence
# ls list of words
# each word represent by i
#w2v_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv.index_to_key])
#                     for ls in X_test])

# %%
# Why is the length of the sentence different than the length of the sentence vector?
#for i, v in enumerate(w2v_vect):
#    print(len(X_test.iloc[i]), len(v))

# %%
# Compute sentence vectors by averaging the word vectors for the words contained in the sentence
w2v_vect_avg = []

for vect in w2v_vect:
    if len(vect)!=0:
        w2v_vect_avg.append(vect.mean(axis=0))
    else:
        w2v_vect_avg.append(np.zeros(100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # Compute sentence vectors by averaging the word vectors for the words contained in the sentence
#       2 w2v_vect_avg = []
# ----> 4 for vect in w2v_vect:
#       5     if len(vect)!=0:
#       6         w2v_vect_avg.append(vect.mean(axis=0))
#
# NameError: name 'w2v_vect' is not defined

# %%
# Are our sentence vector lengths consistent?
#for i, v in enumerate(w2v_vect_avg):
#    print(len(X_test.iloc[i]), len(v))
